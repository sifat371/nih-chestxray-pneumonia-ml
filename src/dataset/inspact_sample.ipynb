# %%
from loader import load_nih_stream

dataset = load_nih_stream()

sample = next(iter(dataset))

# %%
print("\nSample:")
print(sample)
label_id = sample["labels"][0]
label_name = dataset.features["labels"].feature.names[label_id]

print("Label ID:", label_id)
print("Disease name:", label_name)
# Out:
# Sample:
# {'image': <PIL.PngImagePlugin.PngImageFile image mode=L size=1024x1024 at 0x710EED735030>, 'labels': [2]}
# Label ID: 2
# Disease name: Cardiomegaly

# %%
image = sample["image"]
label_id = sample["labels"][0]

# %%
label_name = dataset.features["labels"].feature.names[label_id]

# %%
import matplotlib.pyplot as plt

plt.imshow(image, cmap="gray")
plt.title(f"Label: {label_name}")
plt.axis("off")
plt.show()
